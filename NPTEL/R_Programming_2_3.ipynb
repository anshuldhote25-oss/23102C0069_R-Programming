# %%
# !apt-get update -qq
# !apt-get install -y r-base
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   r-base-core r-recommended
# Suggested packages:
#   elpa-ess r-doc-info | r-doc-pdf r-mathlib r-base-html
# Recommended packages:
#   r-base-html r-doc-html
# The following packages will be upgraded:
#   r-base r-base-core r-recommended
# 3 upgraded, 0 newly installed, 0 to remove and 134 not upgraded.
# Need to get 30.3 MB of archives.
# After this operation, 30.7 kB of additional disk space will be used.
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ r-base-core 4.6.1-1.2204.1 [30.3 MB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ r-base 4.6.1-1.2204.1 [48.1 kB]
# ...

# %% [markdown]
# Vector Addition

# %%
# Load R magic
# %load_ext rpy2.ipython

# %%
# Install rpy2
# !pip install -q rpy2

# %%
# %%R
#
# c(2,3,5,7) + c(-2,-3,-5,8)
# Out:
# [1]  0  0  0 15

# %%
# %%R
#
# c(2,3,5,7) + c(8,9)
# Out:
# [1] 10 12 13 16

# %%
# %%R
#
# c(2,3,5,7) + c(8,9,11)
# Out:
# [1] 10 12 16 15
# In addition: Warning message:
# In c(2, 3, 5, 7) + c(8, 9, 11) :
#   longer object length is not a multiple of shorter object length

# %%
# %%R
#
# c(2,3,5,7) + c(8)
# Out:
# [1] 10 11 13 15

# %%
# %%R
#
# c(2,3,5,7) + 8
# Out:
# [1] 10 11 13 15

# %% [markdown]
# Vector Subtraction

# %%
# %%R
#
# c(2,3,5,7) - c(-2,-3,-5,8)
# Out:
# [1]  4  6 10 -1

# %%
# %%R
#
# c(2,3,5,7) - c(8,9)
# Out:
# [1] -6 -6 -3 -2

# %%
# %%R
#
# c(2,3,5,7) - c(8)
# Out:
# [1] -6 -5 -3 -1

# %%
# %%R
#
# c(2,3,5,7) - 8
# Out:
# [1] -6 -5 -3 -1

# %% [markdown]
# Vector Multiplication

# %%
# %%R
#
# c(2,3,5,7) * c(-2,-3,-5,8)
# Out:
# [1]  -4  -9 -25  56

# %%
# %%R
#
# c(2,3,5,7) * c(8,9)
# Out:
# [1] 16 27 40 63

# %%
# %%R
#
# c(2,3,5,7) * c(8)
# Out:
# [1] 16 24 40 56

# %%
# %%R
#
# c(2,3,5,7) * 8
# Out:
# [1] 16 24 40 56

# %% [markdown]
# Vector Division

# %%
# %%R
#
# c(2,3,5,7) / c(-2,-3,-5,8)
# Out:
# [1] -1.000 -1.000 -1.000  0.875

# %%
# %%R
#
# c(2,3,5,7) / c(8,9)
# Out:
# [1] 0.2500000 0.3333333 0.6250000 0.7777778

# %%
# %%R
#
# c(2,3,5,7) / c(8)
# Out:
# [1] 0.250 0.375 0.625 0.875

# %%
# %%R
#
# c(2,3,5,7) / 8
# Out:
# [1] 0.250 0.375 0.625 0.875

# %% [markdown]
# Scalar Arithmetic

# %%
# %%R
#
# 2 + 5
# Out:
# [1] 7

# %%
# %%R
#
# 2 - 5
# Out:
# [1] -3

# %%
# %%R
#
# 2 * 5
# Out:
# [1] 10

# %%
# %%R
#
# 2 / 5
# Out:
# [1] 0.4

# %% [markdown]
# Assignment

# %%
# %%R
#
# x <- 5
# x
# Out:
# [1] 5

# %%
# %%R
#
# x = 5
# x
# Out:
# [1] 5

# %%
# %%R
#
# a <- 10
# b <- 20
#
# a
# b
# Out:
# [1] 20

# %%
# %%R
#
# x <- c(2,4,6,8)
# x
# Out:
# [1] 2 4 6 8

# %% [markdown]
# Numeric Variable

# %%
# %%R
#
# num <- 25
# num
# Out:
# [1] 25

# %%
# %%R
#
# class(num)
# Out:
# [1] "numeric"

# %% [markdown]
# Character Variable

# %%
# %%R
#
# name <- "R Programming"
# name
# Out:
# [1] "R Programming"

# %%
# %%R
#
# class(name)
# Out:
# [1] "character"

# %% [markdown]
# Logical Variable

# %%
# %%R
#
# flag <- TRUE
# flag
# Out:
# [1] TRUE

# %%
# %%R
#
# class(flag)
# Out:
# [1] "logical"

# %% [markdown]
# Integer Variable

# %%
# %%R
#
# class(num)
# Out:
# [1] "integer"

# %%
# %%R
#
# num <- 25L
# num
# Out:
# [1] 25

# %% [markdown]
# Checking Numeric Values

# %%
# %%R
#
# is.numeric(25)
# Out:
# [1] TRUE

# %%
# %%R
#
# is.numeric("25")
# Out:
# [1] FALSE

# %%
# %%R
#
# is.numeric(c(2,3,4))
# Out:
# [1] TRUE

# %%
# %%R
#
# is.numeric(c("A","B","C"))
# Out:
# [1] FALSE

# %% [markdown]
# Checking Character Values

# %%
# %%R
#
# is.character("Hello")
# Out:
# [1] TRUE

# %%
# %%R
#
# is.character(123)
# Out:
# [1] FALSE

# %%
# %%R
#
# is.character(c("A","B","C"))
# Out:
# [1] TRUE

# %%
# %%R
#
# is.character(c(1,2,3))
# Out:
# [1] FALSE

# %% [markdown]
# Character to Numeric

# %%
# %%R
#
# x <- c("10","20","30")
#
# as.numeric(x)
# Out:
# [1] 10 20 30

# %%
# %%R
#
# x <- "25"
#
# as.numeric(x)
# Out:
# [1] 25

# %%
# %%R
#
# x <- c("10","ABC","30")
#
# as.numeric(x)
# Out:
# [1] 10 NA 30
# In addition: Warning message:
# In (function (expr, envir = parent.frame(), enclos = if (is.list(envir) ||  :
#   NAs introduced by coercion

# %% [markdown]
# Numeric to Character

# %%
# %%R
#
# x <- 25
#
# as.character(x)
# Out:
# [1] "25"

# %%
# %%R
#
# x <- c(10,20,30)
#
# as.character(x)
# Out:
# [1] "10" "20" "30"

# %% [markdown]
# Comments

# %%
# %%R
#
# # This is a comment
#
# 5 + 10
# Out:
# [1] 15

# %%
# %%R
#
# x <- 50      # Store value
# y <- 100     # Store another value
#
# x + y
# Out:
# [1] 150

# %% [markdown]
# Case sensitivity

# %%
# %%R
#
# x <- 100
# X <- 200
#
# x
# X
# Out:
# [1] 200

# %%
# %%R
#
# apple <- 10
# Apple <- 20
#
# apple
# Apple
# Out:
# [1] 20

# %% [markdown]
# Printing Variables

# %%
# %%R
#
# x <- 15
#
# print(x)
# Out:
# [1] 15

# %%
# %%R
#
# name <- "R Language"
#
# print(name)
# Out:
# [1] "R Language"

# %% [markdown]
# Removing Variables

# %%
# %%R
#
# x <- 10
#
# rm(x)

# %%
# %%R
#
# ls()
# Out:
# [1] "a"     "apple" "Apple" "b"     "flag"  "name"  "num"   "X"     "y"

# %% [markdown]
# mode()

# %%
# %%R
#
# x <- 25
# mode(x)
# Out:
# [1] "numeric"

# %%
# %%R
#
# x <- "R Programming"
# mode(x)
# Out:
# [1] "character"

# %%
# %%R
#
# x <- TRUE
# mode(x)
# Out:
# [1] "logical"

# %%
# %%R
#
# x <- c(2,4,6,8)
# mode(x)
# Out:
# [1] "numeric"

# %% [markdown]
# storage.mode()

# %%
# %%R
#
# x <- 25
# storage.mode(x)
# Out:
# [1] "double"

# %%
# %%R
#
# x <- "Hello"
# storage.mode(x)
# Out:
# [1] "character"

# %%
# %%R
#
# x <- TRUE
# storage.mode(x)
# Out:
# [1] "logical"

# %%
# %%R
#
# x <- c(10,20,30)
# storage.mode(x)
# Out:
# [1] "double"

# %% [markdown]
# typeof()

# %%
# %%R
#
# x <- 25
# typeof(x)
# Out:
# [1] "double"

# %%
# %%R
#
# x <- "ABC"
# typeof(x)
# Out:
# [1] "character"

# %%
# %%R
#
# x <- TRUE
# typeof(x)
# Out:
# [1] "logical"

# %%
# %%R
#
# x <- c(1,2,3)
# typeof(x)
# Out:
# [1] "double"

# %% [markdown]
# Length

# %%
# %%R
#
# x <- c(2,4,6,8)
#
# length(x)
# Out:
# [1] 4

# %%
# %%R
#
# x <- c("A","B","C","D","E")
#
# length(x)
# Out:
# [1] 5

# %%
# %%R
#
# length(100)
# Out:
# [1] 1

# %% [markdown]
# Infinity()

# %%
# %%R
#
# 10/0
# Out:
# [1] Inf

# %%
# %%R
#
# -10/0
# Out:
# [1] -Inf

# %%
# %%R
#
# Inf
# Out:
# [1] Inf

# %%
# %%R
#
# is.infinite(Inf)
# Out:
# [1] TRUE

# %%
# %%R
#
# is.infinite(100)
# Out:
# [1] FALSE

# %% [markdown]
# R as a calculator

# %%
2 * 3 - 4 + 5 / 6
# Out:
# 2.8333333333333335

# %%
# Command for BODMAS
(2 + 3) * 5 + 5 - 10
# Out:
# 20

# %%
# Command for BODMAS
(((2 + 3) * 5 + 5) - 10) / 2
# Out:
# 10.0

# %%
# %%R
#
# # Addition of scalar with vector
# c(2,3,5,7) + 10
# Out:
# [1] 12 13 15 17

# %%
# %%R
# # Subtraction of scalar with vector
# c(12,13,15,17) - 10
# Out:
# [1] 2 3 5 7

# %%
# %%R
# # Multiplication of scalar with vector
# c(2,3,5,7) * 10
# Out:
# [1] 20 30 50 70

# %%
# %%R
# # Division of scalar with vector
# c(12,13,15,17) / 10
# Out:
# [1] 1.2 1.3 1.5 1.7

# %% [markdown]
# Week 3

# %%
# %%R
# # Power operations
# 2^3
# 2**3
# 2^0.5
# 2**0.5
# 2^-0.5
# Out:
# [1] 0.7071068

# %%
# %%R
# c(2,3,5,7)^2
# Out:
# [1]  4  9 25 49

# %%
# %%R
# c(2,3,5,7)^c(2,3)
# Out:
# [1]   4  27  25 343

# %%
# %%R
# c(1,2,3,4,5,6)^c(2,3,4)
# Out:
# [1]    1    8   81   16  125 1296

# %%
# %%R
# c(2,3,5,7)^c(2,3,4)
# Out:
# [1]   4  27 625  49
# In addition: Warning message:
# In c(2, 3, 5, 7)^c(2, 3, 4) :
#   longer object length is not a multiple of shorter object length

# %%
# %%R
# # Integer division
# 2 %/% 2
# 5 %/% 2
# 7 %/% 3
# Out:
# [1] 2

# %%
# %%R
# c(2,3,5,7) %/% 2
# Out:
# [1] 1 1 2 3

# %%
# %%R
# c(2,3,5,7) %/% c(2,3)
# Out:
# [1] 1 1 2 2

# %%
# %%R
# c(2,3,5) %/% c(2,3)
# Out:
# [1] 1 1 2
# In addition: Warning message:
# In c(2, 3, 5)%/%c(2, 3) :
#   longer object length is not a multiple of shorter object length

# %%
# %%R
# # Modulo division
# 2 %% 2
# 3 %% 2
# 7 %% 3
# 7 %% 4
# Out:
# [1] 3

# %%
# %%R
# c(2,3,5,7) %% 2
# Out:
# [1] 0 1 1 1

# %%
# %%R
# c(2,3,5,7) %% c(2,3)
# Out:
# [1] 0 0 1 1

# %%
# %%R
# c(2,3,5) %% c(2,3)
# Out:
# [1] 0 0 1
# In addition: Warning message:
# In c(2, 3, 5)%%c(2, 3) :
#   longer object length is not a multiple of shorter object length

# %%
# %%R
# # Max and Min
# max(1.2, 3.4, -7.8)
# max(c(1.2, 3.4, -7.8))
# min(1.2, 3.4, -7.8)
# min(c(1.2, 3.4, -7.8))
# Out:
# [1] -7.8

# %%
# %%R
# # Mean
# mean(2, 3, 4)
# mean(c(2, 3, 4))
# Out:
# [1] 3

# %%
# %%R
# # abs and sqrt
# abs(-4)
# abs(c(-1,-2,-3,4,5))
# sqrt(4)
# sqrt(c(4,9,16,25))
# Out:
# [1] 2 3 4 5

# %%
# %%R
# # sum and prod
# sum(c(2,3,5,7))
# prod(c(2,3,5,7))
# Out:
# [1] 210

# %%
# %%R
# # round
# round(1.23)
# round(1.83)
# Out:
# [1] 2

# %%
# %%R
# # log functions
# log(10)
# log(exp(1))
# log(c(10, 100, 1000))
# log10(10)
# log10(100)
# log10(c(10, 100, 1000))
# Out:
# [1] 1 2 3

# %%
# %%R
# # Assignments
# x1 = c(1,2,3,4)
# x1
# x2 = x1^2
# x2
# Out:
# [1]  1  4  9 16

# %%
# %%R
# c(1,2,3,4) + sum(c(1,2,3,4)) * prod(c(1,2))
# abs(c(1,2,3,4) - sum(c(1,2,3,4))*prod(c(1,2)))
# Out:
# [1] 19 18 17 16

# %%
# %%R
# # Matrix - default column-wise fill
# x = matrix(nrow=4, ncol=2, data=c(1,2,3,4,5,6,7,8))
# x
# Out:
#      [,1] [,2]
# [1,]    1    5
# [2,]    2    6
# [3,]    3    7
# [4,]    4    8

# %%
# %%R
# # Access single element
# x[3,2]
# Out:
# [1] 7

# %%
# %%R
# # Matrix - explicit byrow = FALSE
# x = matrix(nrow=4, ncol=2, data=c(1,2,3,4,5,6,7,8), byrow = FALSE)
# x
# Out:
#      [,1] [,2]
# [1,]    1    5
# [2,]    2    6
# [3,]    3    7
# [4,]    4    8

# %%
# %%R
# # Matrix - byrow = TRUE
# y = matrix(nrow=4, ncol=2, data=c(1,2,3,4,5,6,7,8), byrow = TRUE)
# y
# Out:
#      [,1] [,2]
# [1,]    1    2
# [2,]    3    4
# [3,]    5    6
# [4,]    7    8

# %%
# %%R
# # Matrix properties
# dim(x)
# nrow(x)
# ncol(x)
# mode(x)
# attributes(x)
# Out:
# $dim
# [1] 4 2
